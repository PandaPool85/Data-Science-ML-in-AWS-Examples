# %%
import warrant

# %%
# !pip freeze
# Out:
# alabaster==0.7.12
# alembic==1.0.10
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.2
# apache-airflow==1.10.5
# apispec==3.0.0
# appdirs==1.4.3
# asciimatics==1.11.0
# asn1crypto==0.24.0
# astroid==2.2.5
# astropy==3.1.2
# async-generator==1.10
# atomicwrites==1.3.0
# atpublic==1.0
# attrs==19.1.0
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.7.1
# bitarray==0.8.3
# bkcharts==0.2
# bleach==3.1.0
# blinker==1.4
# bokeh==1.0.4
# boto==2.49.0
# boto3==1.9.250
# botocore==1.12.250
# Bottleneck==1.2.1
# bravado==10.4.1
# bravado-core==5.13.1
# cached-property==1.5.1
# certifi==2019.3.9
# certipy==0.1.3
# cffi==1.12.2
# chardet==3.0.4
# cli-helpers==1.2.1
# Click==7.0
# cloudpickle==0.8.0
# clyent==1.2.2
# colorama==0.4.1
# colorlog==4.0.2
# conda==4.6.14
# conda-build==3.17.8
# conda-verify==3.1.1
# configobj==5.0.6
# configparser==3.5.3
# contextlib2==0.5.5
# croniter==0.3.30
# ...

# %%
# !python --version
# Out:
# Python 3.7.3

# %%
# !type python
# Out:
# python is /home/centos/anaconda3/bin/python

# %%
import sys

sys.executable
# Out:
# '/DIDA/sw/Envs/cognito-test-env/bin/python'

# %%
from warrant import Cognito
import requests
import json
import datetime

COGNITO_POOL_ID = 'us-east-1_j2un39qR7'
COGNITO_APP_ID = '43jgfer3g7e9ait2o9fvpfs8r2'
COGNITO_USERNAME = 'pegasys_api_test_user'
COGNITO_PASSWORD = 'Welcome2API!'

APPSYNC_URL = 'https://gz2j3dzh5fdsbmw6vtyivzv6xu.appsync-api.us-east-1.amazonaws.com/graphql'
APPSYNC_QUERY = 'query hello { getHelloWorld { json } }'

# Authenticate with Cognito
print("Authenticating with Cognito to get a JWT.  {}".format(datetime.datetime.now()))
u = Cognito(COGNITO_POOL_ID,COGNITO_APP_ID,username=COGNITO_USERNAME)
u.authenticate(password=COGNITO_PASSWORD)
print("JWT")
print("Copy text between the dashed lines below.  Do NOT copy the JWT BEGIN and JWT END dashed lines.")
print("--------------------- JWT BEGIN ------------------")
print("{}".format(u.id_token))
print("--------------------- JWT END ------------------")

# Call Appsync
data = {"query": APPSYNC_QUERY}
headers = {"Content-Type":"application/graphql","Authorization": "{}".format(u.id_token)}
resp = requests.post(APPSYNC_URL,headers=headers,data=json.dumps(data))
print(json.dumps(resp.json(),indent=4))
# Out:
# Authenticating with Cognito to get a JWT.  2019-11-01 15:00:23.479268
# JWT
# Copy text between the dashed lines below.  Do NOT copy the JWT BEGIN and JWT END dashed lines.
# --------------------- JWT BEGIN ------------------
# eyJraWQiOiJOUHFhSzJKb0EyaEFVMkJHVTVoc3hZREZqZ1hLUG1xcFRRaDkzRG9vWVwvVT0iLCJhbGciOiJSUzI1NiJ9.....KvmTr99eo_lm7WCl-Rn7Il5hQWtajrCOPlbLcvL0vf92kzlQczolYbVvLsNbTVuf1okgijkQuesZBkk6OStNwvZfUmnzORpfZbCpLQUezKNhqXd7m9mmSRoLmcbvBDV9-MI2zE7ycNXnEfPoeUmQldTEvvIy16tNKlxRUZ_8hiEmuUEavTPEQDRACyCjJLOIO-53LBaOUdsSKJH0WVBdiqEg_zVkvPvanEGkZQdKmsgc4nzZ9ztJAjiijc4SPHP24lLzy8B166YNu720-qG1YZJj3rhp_fyk2vwuvL1XqAnn6VSz5PFECuzNOK-v0sNNmd6Cp6yGoXWTjgtmHRSdfQ
# --------------------- JWT END ------------------
# {
#     "data": {
#         "getHelloWorld": {
#             "json": "\"Hello from Lambda!\""
#         }
#     }
# }

# %%
import os
os.environ["AWS_CA_BUNDLE"] = "/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem"
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
print("{}".format(os.environ))
# Out:
# environ({'SHELL': '/bin/bash', 'JPY_API_TOKEN': '078d27dc850143bd973eeccb32a71ad0', 'USER': 'dummy_user', 'JUPYTERHUB_BASE_URL': '/', 'JUPYTERHUB_CLIENT_ID': 'jupyterhub-user-dummy_user', 'JUPYTERHUB_API_TOKEN': '078d27dc850143bd973eeccb32a71ad0', 'PATH': '/home/centos/anaconda3/bin/:/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/home/centos/anaconda3/bin', 'PWD': '/home/dummy_user', 'JUPYTERHUB_SERVER_NAME': '', 'LANG': 'en_US.UTF-8', 'JUPYTERHUB_API_URL': 'http://127.0.0.1:8081/hub/api', 'SHLVL': '0', 'HOME': '/home/dummy_user', 'JUPYTERHUB_USER': 'dummy_user', 'JUPYTERHUB_ACTIVITY_URL': 'http://127.0.0.1:8081/hub/api/users/dummy_user/activity', 'JUPYTERHUB_OAUTH_CALLBACK_URL': '/user/dummy_user/oauth_callback', 'JUPYTERHUB_HOST': '', 'JUPYTERHUB_SERVICE_PREFIX': '/user/dummy_user/', 'JPY_PARENT_PID': '77085', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline', 'AWS_DEFAULT_REGION': 'us-east-1
# ...

# %%
# !find /DIDA/sw/Envs/cognito-test-env -name "cacert.pem" -print
# Out:
# /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/certifi/cacert.pem
# /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/pip/_vendor/certifi/cacert.pem
# /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/cacert.pem
# /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/vendored/requests/cacert.pem

# %%
# !wget https://mirror.syngentaaws.org/pub/syngenta/deployment/ca-certificates/SyngentaIntCA.cer.pem
# !wget https://mirror.syngentaaws.org/pub/syngenta/deployment/ca-certificates/SyngentaRootCA.cer.pem
# Out:
# --2019-10-23 17:47:41--  https://mirror.syngentaaws.org/pub/syngenta/deployment/ca-certificates/SyngentaIntCA.cer.pem
# Resolving mirror.syngentaaws.org (mirror.syngentaaws.org)... 10.127.40.242
# Connecting to mirror.syngentaaws.org (mirror.syngentaaws.org)|10.127.40.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2754 (2.7K) [application/pkix-cert]
# Saving to: ‘SyngentaIntCA.cer.pem’
#
# 100%[======================================>] 2,754       --.-K/s   in 0s
#
# 2019-10-23 17:47:41 (164 MB/s) - ‘SyngentaIntCA.cer.pem’ saved [2754/2754]
#
# --2019-10-23 17:47:41--  https://mirror.syngentaaws.org/pub/syngenta/deployment/ca-certificates/SyngentaRootCA.cer.pem
# Resolving mirror.syngentaaws.org (mirror.syngentaaws.org)... 10.127.40.242
# Connecting to mirror.syngentaaws.org (mirror.syngentaaws.org)|10.127.40.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2032 (2.0K) [application/pkix-cert]
# ...

# %%
# !cat SyngentaIntCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/certifi/cacert.pem
# !cat SyngentaIntCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/pip/_vendor/certifi/cacert.pem
# !cat SyngentaIntCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/cacert.pem
# !cat SyngentaIntCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/vendored/requests/cacert.pem

# !cat SyngentaRootCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/certifi/cacert.pem
# !cat SyngentaRootCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/pip/_vendor/certifi/cacert.pem
# !cat SyngentaRootCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/cacert.pem
# !cat SyngentaRootCA.cer.pem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/botocore/vendored/requests/cacert.pempem >> /DIDA/sw/Envs/cognito-test-env/lib/python3.7/site-packages/certifi/cacert.pem

# %%
# !whoami
# !pwd
# !df -h .
# Out:
# dummy_user
# /home/dummy_user
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/xvda1      100G   57G   44G  57% /
